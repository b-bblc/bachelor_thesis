# %% [markdown]
# # Dependency Parsing for Russian EDUs (.rs3)
#
# This notebook demonstrates how to:
# - Extract Elementary Discourse Units (EDUs) from a Russian RST .rs3 file
# - Parse each EDU using dependency parsing (spaCy)
# - Visualize the dependency trees for the first 5 EDUs
#
# All comments and code are in English. Adjust file paths as needed.

# %%
import spacy
import glob
from spacy import displacy
import xml.etree.ElementTree as ET

# %% [markdown]
# ## 2. Load the Russian spaCy Model

# %%
nlp_ru = spacy.load('ru_core_news_sm')

# %% [markdown]
# ## 3. Extract EDUs from the Russian .rs3 File

# %%
nlp_ru = spacy.load('ru_core_news_sm')

rs3_files = glob.glob('RuRsTreebank_full/**/*.rs3', recursive=True)

for rs3_path in rs3_files:
    print(f"Processing file: {rs3_path}")
    root = ET.parse(rs3_path).getroot()
    edus = []
    for segment in root.findall('.//segment'):
        edu_text = segment.text.strip() if segment.text else ''
        if edu_text:
            edus.append(edu_text)
    print(f"Total EDUs in this file: {len(edus)}")
    for idx, edu in enumerate(edus[:2]):
        print(f"EDU {idx+1}: {edu}")
        doc = nlp_ru(edu)
        for token in doc:
            print(token.text, token.dep_, token.head.text)
        print('-' * 20)
# Out:
# Processing file: RuRsTreebank_full/blogs/test/blogs_36.rs3
# Total EDUs in this file: 97
# EDU 1: ##### https://ff-mag.livejournal.com/61921.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ff-mag.livejournal.com/61921.html appos #
# --------------------
# EDU 2: ##### Завтрак: обязательное условие для всех, кто хочет быть в форме, или уловка маркетологов?
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Завтрак appos #
# : punct условие
# обязательное amod условие
# условие parataxis Завтрак
# для case всех
# всех nmod условие
# , punct хочет
# кто nsubj хочет
# хочет acl:relcl всех
# быть cop форме
# в case форме
# форме obl хочет
# , punct уловка
# или cc уловка
# уловка conj условие
# маркетологов nmod уловка
# ? punct Завтрак
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_1.rs3
# Total EDUs in this file: 102
# EDU 1: ##### https://kosmetista.ru/blog/uhodovaya-kosmetika/97696.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/uhodovaya-kosmetika/97696.html appos #
# --------------------
# EDU 2: ##### Бюджетная косметика с пребиотиками от Chocolatte
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Бюджетная amod косметика
# косметика appos #
# с case пребиотиками
# пребиотиками nmod косметика
# от case Chocolatte
# Chocolatte nmod косметика
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_57.rs3
# Total EDUs in this file: 49
# EDU 1: ##### https://putnik1.livejournal.com/7594285.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://putnik1.livejournal.com/7594285.html appos #
# --------------------
# EDU 2: ##### КВАНТУНСКАЯ ВОЛОСТЬ
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# КВАНТУНСКАЯ appos #
# ВОЛОСТЬ appos #
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_43.rs3
# Total EDUs in this file: 102
# EDU 1: ##### https://habr.com/ru/post/460161/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://habr.com/ru/post/460161/ appos #
# --------------------
# EDU 2: ##### FusionPBX и ACL
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# FusionPBX appos #
# и cc ACL
# ACL conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_93.rs3
# Total EDUs in this file: 254
# EDU 1: ##### https://ru-travel.livejournal.com/33766823.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33766823.html appos #
# --------------------
# EDU 2: ##### Маврикий
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Маврикий appos #
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_85.rs3
# Total EDUs in this file: 63
# EDU 1: ##### https://t.me/chtobitchto/165
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://t.me/chtobitchto/165 punct #
# --------------------
# EDU 2: ##### Что bitch что?, [28.02.19 22:34]
# # nsubj что
# # appos #
# # punct #
# # punct #
# # appos #
# Что nsubj что
# bitch nsubj Что
# что ROOT что
# ? punct что
# , punct 28.02.19
# [ punct 28.02.19
# 28.02.19 ROOT 28.02.19
# 22:34 appos 28.02.19
# ] punct 28.02.19
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_71.rs3
# Total EDUs in this file: 392
# EDU 1: ##### https://evo-lutio.livejournal.com/930925.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://evo-lutio.livejournal.com/930925.html appos #
# --------------------
# EDU 2: ##### Формула красного поля
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Формула appos #
# красного amod поля
# поля nmod Формула
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_64.rs3
# Total EDUs in this file: 135
# EDU 1: ##### https://marina-yudenich.livejournal.com/1393035.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://marina-yudenich.livejournal.com/1393035.html appos #
# --------------------
# EDU 2: ##### Странная история министра Улюкаева и очень редкого вина
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Странная amod история
# история appos #
# министра nmod история
# Улюкаева appos министра
# и cc вина
# очень advmod редкого
# редкого amod вина
# вина conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_15.rs3
# Total EDUs in this file: 163
# EDU 1: ##### https://my-first-time.livejournal.com/569638.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/569638.html flat:foreign #
# --------------------
# EDU 2: ##### Первый раз сдача экзамена по ПДД
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Первый amod раз
# раз obl сдача
# сдача ROOT сдача
# экзамена nmod сдача
# по case ПДД
# ПДД nmod сдача
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_29.rs3
# Total EDUs in this file: 133
# EDU 1: ##### https://dpmmax.livejournal.com/824738.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://dpmmax.livejournal.com/824738.html appos #
# --------------------
# EDU 2: ##### Посредник хорошего настроения и счастья: серотонин
# # nsubj серотонин
# # appos #
# # punct #
# # punct #
# # punct #
# Посредник appos #
# хорошего amod настроения
# настроения nmod Посредник
# и cc счастья
# счастья conj настроения
# : punct серотонин
# серотонин ROOT серотонин
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_100.rs3
# Total EDUs in this file: 97
# EDU 1: ##### https://ru-travel.livejournal.com/33778768.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33778768.html appos #
# --------------------
# EDU 2: ##### Покупка отзывов на Букинге
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Покупка appos #
# отзывов nmod Покупка
# на case Букинге
# Букинге nmod Покупка
# --------------------
# Processing file: RuRsTreebank_full/blogs/test/blogs_8.rs3
# Total EDUs in this file: 114
# EDU 1: ##### https://kosmetista.ru/blog/uhodovaya-kosmetika/99379.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/uhodovaya-kosmetika/99379.html appos #
# --------------------
# EDU 2: ##### Мой лучший крем A'PIEU c мадекассосидом
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Мой det крем
# лучший amod крем
# крем ROOT крем
# A'PIEU appos крем
# c case мадекассосидом
# мадекассосидом nmod крем
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_21.rs3
# Total EDUs in this file: 348
# EDU 1: ##### https://odin-moy-den.livejournal.com/2215985.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://odin-moy-den.livejournal.com/2215985.html appos #
# --------------------
# EDU 2: ##### Всем здравствуйте!
# # obj здравствуйте
# # appos #
# # punct #
# # punct #
# # punct здравствуйте
# Всем obj здравствуйте
# здравствуйте ROOT здравствуйте
# ! punct здравствуйте
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_35.rs3
# Total EDUs in this file: 103
# EDU 1: ##### https://freshandfree.ru/posts/spine/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://freshandfree.ru/posts/spine/ flat:foreign #
# --------------------
# EDU 2: ##### Жизнь за компьютером: к каким проблемам со спиной нас приводят гаджеты?
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Жизнь appos #
# за case компьютером
# компьютером nmod Жизнь
# : punct приводят
# к case проблемам
# каким det проблемам
# проблемам obl приводят
# со case спиной
# спиной nmod проблемам
# нас obj приводят
# приводят parataxis Жизнь
# гаджеты nsubj приводят
# ? punct Жизнь
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_4.rs3
# Total EDUs in this file: 371
# EDU 1: ##### https://kosmetista.ru/blog/pricheski/97137.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/pricheski/97137.html appos #
# --------------------
# EDU 2: ##### Из хенно-басменной леди в обесцвеченно-красную диву: сравнение ухода до и после, выводы и планы
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Из case леди
# хенно amod леди
# - amod леди
# басменной amod леди
# леди nmod #
# в case диву
# обесцвеченно amod диву
# - amod диву
# красную amod диву
# диву nmod леди
# : punct сравнение
# сравнение parataxis леди
# ухода nmod сравнение
# до advmod сравнение
# и cc после
# после conj до
# , punct выводы
# выводы conj сравнение
# и cc планы
# планы conj сравнение
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_5.rs3
# Total EDUs in this file: 134
# EDU 1: ##### https://kosmetista.ru/blog/pricheski/94010.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/pricheski/94010.html appos #
# --------------------
# EDU 2: ##### Восточная сказка для волос с натуральной косметикой Zeitun
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Восточная amod сказка
# сказка appos #
# для case волос
# волос nmod сказка
# с case косметикой
# натуральной amod косметикой
# косметикой nmod волос
# Zeitun flat:foreign #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_34.rs3
# Total EDUs in this file: 186
# EDU 1: ##### http://salatshop.ru/post/10-sochetanie
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://salatshop.ru/post/10-sochetanie appos #
# --------------------
# EDU 2: ##### Простота — залог здоровья. 10 принципов сочетания продуктов
# # nsubj залог
# # appos #
# # punct #
# # punct #
# # punct #
# Простота nsubj залог
# — punct залог
# залог ROOT залог
# здоровья nmod залог
# . punct залог
# 10 nummod принципов
# принципов ROOT принципов
# сочетания nmod принципов
# продуктов nmod сочетания
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_20.rs3
# Total EDUs in this file: 232
# EDU 1: ##### https://odin-moy-den.livejournal.com/2216337.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://odin-moy-den.livejournal.com/2216337.html appos #
# --------------------
# EDU 2: ##### ОМНГ (из жизни таксиста одного городка)
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# ОМНГ appos #
# ( punct жизни
# из case жизни
# жизни parataxis ОМНГ
# таксиста nmod жизни
# одного nummod городка
# городка nmod таксиста
# ) punct жизни
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_22.rs3
# Total EDUs in this file: 478
# EDU 1: ##### https://odin-moy-den.livejournal.com/2214902.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://odin-moy-den.livejournal.com/2214902.html appos #
# --------------------
# EDU 2: ##### Субботний день эмигрантки в Праге.
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Субботний amod день
# день appos #
# эмигрантки nmod день
# в case Праге
# Праге nmod эмигрантки
# . punct #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_7.rs3
# Total EDUs in this file: 58
# EDU 1: ##### https://kosmetista.ru/blog/uhodovaya-kosmetika/96561.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/uhodovaya-kosmetika/96561.html appos #
# --------------------
# EDU 2: ##### Klairs Rich Moist Soothing Cream - Увлажняющий и успокаивающий крем от Klairs
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Klairs flat:foreign #
# Rich flat:foreign Klairs
# Moist flat:foreign Klairs
# Soothing flat:foreign Klairs
# Cream flat:foreign Klairs
# - appos #
# Увлажняющий appos #
# и cc успокаивающий
# успокаивающий conj #
# крем obj успокаивающий
# от case Klairs
# Klairs obl успокаивающий
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_6.rs3
# Total EDUs in this file: 117
# EDU 1: ##### https://kosmetista.ru/blog/uhodovaya-kosmetika/96446.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/uhodovaya-kosmetika/96446.html appos #
# --------------------
# EDU 2: ##### Косметика поколения Z: Milk Makeup Urban Defense Mask
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Косметика appos #
# поколения nmod Косметика
# Z appos поколения
# : punct Milk
# Milk appos #
# Makeup flat:foreign Milk
# Urban flat:foreign Milk
# Defense flat:foreign Milk
# Mask flat:foreign Milk
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_23.rs3
# Total EDUs in this file: 183
# EDU 1: ##### https://my-first-time.livejournal.com/575558.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/575558.html appos #
# --------------------
# EDU 2: ##### Привет, сообщество.
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Привет appos #
# , punct сообщество
# сообщество conj Привет
# . punct Привет
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_37.rs3
# Total EDUs in this file: 56
# EDU 1: ##### https://airfit.ru/kak-stavit-stopy-vo-vremya-bega
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://airfit.ru/kak-stavit-stopy-vo-vremya-bega appos #
# --------------------
# EDU 2: ##### Постановка ноги во время пробежек
# # punct пробежек
# # appos #
# # punct #
# # punct #
# # punct #
# Постановка appos #
# ноги nmod Постановка
# во case пробежек
# время fixed во
# пробежек ROOT пробежек
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_33.rs3
# Total EDUs in this file: 126
# EDU 1: ##### http://fitness-blog-ua.blogspot.com/2017/09/blog-post.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://fitness-blog-ua.blogspot.com/2017/09/blog-post.html appos #
# --------------------
# EDU 2: ##### Год [почти] без сахара
# # punct сахара
# # appos #
# # punct #
# # punct #
# # punct #
# Год appos #
# [ punct почти
# почти appos Год
# ] punct почти
# без case сахара
# сахара ROOT сахара
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_27.rs3
# Total EDUs in this file: 80
# EDU 1: ##### http://fitness-blog-ua.blogspot.com/2019/03/blog-post.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://fitness-blog-ua.blogspot.com/2019/03/blog-post.html appos #
# --------------------
# EDU 2: ##### Пшено вместо киноа, клюква вместо годжи: Альтернатива экзотическим продуктам
# # nsubj:pass Пшено
# # appos #
# # punct #
# # appos #
# # appos #
# Пшено ROOT Пшено
# вместо case киноа
# киноа obl Пшено
# , punct клюква
# клюква conj Пшено
# вместо case годжи
# годжи nmod клюква
# : punct Альтернатива
# Альтернатива parataxis клюква
# экзотическим amod продуктам
# продуктам iobj Пшено
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_2.rs3
# Total EDUs in this file: 138
# EDU 1: ##### https://kosmetista.ru/blog/uhodovaya-kosmetika/95993.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/uhodovaya-kosmetika/95993.html appos #
# --------------------
# EDU 2: ##### Регенерация как она есть? Набор средств ухода Extra-Firming от Clarins
# # punct есть
# # appos #
# # punct #
# # punct #
# # punct #
# Регенерация appos #
# как mark есть
# она nsubj есть
# есть ROOT есть
# ? punct есть
# Набор ROOT Набор
# средств nmod Набор
# ухода nmod средств
# Extra nmod ухода
# - appos ухода
# Firming nmod ухода
# от case Clarins
# Clarins nmod Набор
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_3.rs3
# Total EDUs in this file: 57
# EDU 1: ##### https://kosmetista.ru/blog/otzivi/94681.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://kosmetista.ru/blog/otzivi/94681.html appos #
# --------------------
# EDU 2: ##### Lime Crime Velvetines #Red Velvet
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Lime flat:foreign #
# Crime flat:foreign Lime
# Velvetines flat:foreign Lime
# # punct #
# Red flat:foreign #
# Velvet flat:foreign #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_26.rs3
# Total EDUs in this file: 83
# EDU 1: ##### https://lena-miro.ru/1393544.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://lena-miro.ru/1393544.html appos #
# --------------------
# EDU 2: ##### Три секрета питания
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Три nummod:gov секрета
# секрета ROOT секрета
# питания nmod секрета
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_32.rs3
# Total EDUs in this file: 128
# EDU 1: ##### https://daryakarelina.com/podschet-kalorij-ne-tochnaya-nauka
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://daryakarelina.com/podschet-kalorij-ne-tochnaya-nauka appos #
# --------------------
# EDU 2: ##### Подсчет калорий - не точная наука
# # nsubj наука
# # appos #
# # punct #
# # punct #
# # punct #
# Подсчет nsubj наука
# калорий nmod Подсчет
# - punct Подсчет
# не advmod точная
# точная amod наука
# наука ROOT наука
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_24.rs3
# Total EDUs in this file: 124
# EDU 1: ##### https://my-first-time.livejournal.com/574519.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/574519.html appos #
# --------------------
# EDU 2: ##### Мой первый визит к стоматологу
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Мой det визит
# первый amod визит
# визит ROOT визит
# к case стоматологу
# стоматологу nmod визит
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_30.rs3
# Total EDUs in this file: 97
# EDU 1: ##### https://glagolas.livejournal.com/175134.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://glagolas.livejournal.com/175134.html appos #
# --------------------
# EDU 2: ##### Когда лучше чистить зубы
# # punct лучше
# # appos #
# # punct #
# # appos #
# # punct #
# Когда advmod лучше
# лучше ROOT лучше
# чистить csubj лучше
# зубы nsubj лучше
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_18.rs3
# Total EDUs in this file: 172
# EDU 1: ##### https://my-first-time.livejournal.com/565289.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/565289.html appos #
# --------------------
# EDU 2: ##### Мой первый раз, когда я выбила "бесплатное" медобслуживание по полису ОМС
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Мой det раз
# первый amod раз
# раз ROOT раз
# , punct выбила
# когда mark выбила
# я nsubj выбила
# выбила acl:relcl раз
# " punct бесплатное
# бесплатное amod медобслуживание
# " punct бесплатное
# медобслуживание obj выбила
# по case полису
# полису nmod медобслуживание
# ОМС nmod полису
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_19.rs3
# Total EDUs in this file: 293
# EDU 1: ##### https://odin-moy-den.livejournal.com/2211666.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://odin-moy-den.livejournal.com/2211666.html appos #
# --------------------
# EDU 2: ##### Один день в Вене с Питером Брейгелем
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Один nummod день
# день punct #
# в case Вене
# Вене nmod день
# с case Питером
# Питером nmod день
# Брейгелем flat:name Питером
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_31.rs3
# Total EDUs in this file: 175
# EDU 1: ##### http://aelita544.ru/post455819547
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://aelita544.ru/post455819547 flat:foreign #
# --------------------
# EDU 2: ##### Упражнения, которые сделают точеными ваши руки и спину
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Упражнения appos #
# , punct сделают
# которые nsubj сделают
# сделают acl:relcl #
# точеными xcomp сделают
# ваши det руки
# руки obj сделают
# и cc спину
# спину conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_25.rs3
# Total EDUs in this file: 115
# EDU 1: ##### https://my-first-time.livejournal.com/574158.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/574158.html appos #
# --------------------
# EDU 2: ##### Как я впервые сморчки искала.
# # nsubj искала
# # appos #
# # punct #
# # punct #
# # punct #
# Как advmod искала
# я nsubj искала
# впервые advmod искала
# сморчки obj искала
# искала ROOT искала
# . punct искала
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_81.rs3
# Total EDUs in this file: 99
# EDU 1: ##### http://www.imorganic.ru/bioplim/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://www.imorganic.ru/bioplim/ flat:foreign #
# --------------------
# EDU 2: ##### Одноразовое — вот где начинаются все проблемы
# # punct начинаются
# # appos #
# # punct #
# # punct #
# # appos #
# Одноразовое appos #
# — punct начинаются
# вот advmod где
# где advmod начинаются
# начинаются ROOT начинаются
# все det проблемы
# проблемы nsubj начинаются
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_95.rs3
# Total EDUs in this file: 222
# EDU 1: ##### https://forum.awd.ru/viewtopic.php?t=357349_sid=d6736074d8cc023e5a0c79515f633c84
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://forum.awd.ru/viewtopic.php?t=357349_sid=d6736074d8cc023e5a0c79515f633c84 appos #
# --------------------
# EDU 2: ##### Два дня в Стамбуле: организованное и вольное шатание по городу между рейсами в ЮВА
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Два nummod:gov дня
# дня punct #
# в case Стамбуле
# Стамбуле nmod дня
# : punct шатание
# организованное amod шатание
# и cc вольное
# вольное conj организованное
# шатание parataxis Стамбуле
# по case городу
# городу nmod шатание
# между case рейсами
# рейсами nmod шатание
# в case ЮВА
# ЮВА nmod шатание
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_94.rs3
# Total EDUs in this file: 261
# EDU 1: ##### https://ru-travel.livejournal.com/33764838.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33764838.html appos #
# --------------------
# EDU 2: ##### Бежецк, ч.2 - немного уютной старины
# # punct старины
# # appos #
# # punct #
# # punct #
# # appos #
# Бежецк appos #
# , punct ч.2
# ч.2 appos #
# - punct ч.2
# немного advmod уютной
# уютной amod старины
# старины ROOT старины
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_80.rs3
# Total EDUs in this file: 202
# EDU 1: ##### https://pudgik.livejournal.com/1367624.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://pudgik.livejournal.com/1367624.html appos #
# --------------------
# EDU 2: ##### Зоошиза и сохранятели семьи: судьба одной квартиры
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Зоошиза nmod #
# и cc сохранятели
# сохранятели conj Зоошиза
# семьи nmod сохранятели
# : punct судьба
# судьба ROOT судьба
# одной nummod квартиры
# квартиры nmod судьба
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_69.rs3
# Total EDUs in this file: 118
# EDU 1: ##### https://dpmmax.livejournal.com/851297.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://dpmmax.livejournal.com/851297.html appos #
# --------------------
# EDU 2: ##### Хорошо забытое старое?
# # nsubj старое
# # appos #
# # punct #
# # appos #
# # punct #
# Хорошо advmod забытое
# забытое acl старое
# старое ROOT старое
# ? punct старое
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_55.rs3
# Total EDUs in this file: 73
# EDU 1: ##### https://alexandr-rogers.livejournal.com/1161320.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://alexandr-rogers.livejournal.com/1161320.html appos #
# --------------------
# EDU 2: ##### 12:38 pm: Картина маслом
# # punct маслом
# # appos #
# # punct #
# # punct #
# # appos #
# 12:38 appos #
# pm flat 12:38
# : punct Картина
# Картина parataxis #
# маслом ROOT маслом
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_41.rs3
# Total EDUs in this file: 120
# EDU 1: ##### https://habr.com/ru/company/kaspersky/blog/460135/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://habr.com/ru/company/kaspersky/blog/460135/ appos #
# --------------------
# EDU 2: ##### Security Week 29: уязвимость в сервисе Zoom, безопасность и драма
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Security flat:foreign #
# Week flat:foreign #
# 29 appos #
# : punct уязвимость
# уязвимость ROOT уязвимость
# в case сервисе
# сервисе nmod уязвимость
# Zoom appos сервисе
# , punct безопасность
# безопасность conj уязвимость
# и cc драма
# драма conj уязвимость
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_96.rs3
# Total EDUs in this file: 195
# EDU 1: ##### https://ru-travel.livejournal.com/33786605.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33786605.html appos #
# --------------------
# EDU 2: ##### Ренон, Доломитовые Альпы: красота, от которой захватывает дух
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Ренон appos #
# , punct Альпы
# Доломитовые amod Альпы
# Альпы appos #
# : punct красота
# красота parataxis Альпы
# , punct захватывает
# от case которой
# которой obl захватывает
# захватывает acl:relcl красота
# дух obj захватывает
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_82.rs3
# Total EDUs in this file: 106
# EDU 1: ##### http://www.imorganic.ru/oodi/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://www.imorganic.ru/oodi/ appos #
# --------------------
# EDU 2: ##### Библиотеки как часть городской экокультуры
# # punct часть
# # appos #
# # punct #
# # punct #
# # punct #
# Библиотеки appos #
# как case часть
# часть ROOT часть
# городской amod экокультуры
# экокультуры nmod часть
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_83.rs3
# Total EDUs in this file: 42
# EDU 1: ##### https://t.me/corpequities/276
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://t.me/corpequities/276 punct #
# --------------------
# EDU 2: ##### «Компании делают что-то хорошее только там, где они делают что-то плохое», —
# # nsubj делают
# # appos #
# # punct #
# # appos #
# # appos #
# « punct делают
# Компании nsubj делают
# делают ROOT делают
# что obj делают
# - obj делают
# то obj делают
# хорошее obj делают
# только advmod там
# там advmod хорошее
# , punct делают
# где advmod делают
# они nsubj делают
# делают acl:relcl там
# что obj делают
# - obj делают
# то obj делают
# плохое obj делают
# » punct делают
# , punct делают
# — punct делают
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_97.rs3
# Total EDUs in this file: 237
# EDU 1: ##### https://ru-travel.livejournal.com/33781977.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33781977.html appos #
# --------------------
# EDU 2: ##### Грузия: Кватахеви и Магалаанткари.
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Грузия appos #
# : punct Кватахеви
# Кватахеви parataxis Грузия
# и cc Магалаанткари
# Магалаанткари conj Кватахеви
# . punct #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_40.rs3
# Total EDUs in this file: 158
# EDU 1: ##### https://habr.com/ru/company/ruvds/blog/460016/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://habr.com/ru/company/ruvds/blog/460016/ appos #
# --------------------
# EDU 2: ##### Признаки настоящих программистов-сеньоров и методы их выслеживания в дикой природе
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Признаки appos #
# настоящих amod программистов
# программистов nmod Признаки
# - nmod Признаки
# сеньоров nmod Признаки
# и cc методы
# методы conj Признаки
# их nmod выслеживания
# выслеживания nmod методы
# в case природе
# дикой amod природе
# природе nmod #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_54.rs3
# Total EDUs in this file: 197
# EDU 1: ##### https://alexandr-rogers.livejournal.com/1162207.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://alexandr-rogers.livejournal.com/1162207.html appos #
# --------------------
# EDU 2: ##### 05:55 pm: Сводка с информационных фронтов
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# 05:55 appos #
# pm flat 05:55
# : punct Сводка
# Сводка ROOT Сводка
# с case фронтов
# информационных amod фронтов
# фронтов nmod Сводка
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_68.rs3
# Total EDUs in this file: 115
# EDU 1: ##### https://gelena-s.livejournal.com/296755.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://gelena-s.livejournal.com/296755.html appos #
# --------------------
# EDU 2: ##### Про имидж
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Про case имидж
# имидж nmod #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_50.rs3
# Total EDUs in this file: 213
# EDU 1: ##### https://tonsky.livejournal.com/322258.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://tonsky.livejournal.com/322258.html appos #
# --------------------
# EDU 2: ##### ICFPC 2019
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# ICFPC appos #
# 2019 appos #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_44.rs3
# Total EDUs in this file: 184
# EDU 1: ##### https://blog.allo.ua/lg-g7-thinq-review_2018-07-12/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://blog.allo.ua/lg-g7-thinq-review_2018-07-12/ appos #
# --------------------
# EDU 2: ##### Обзор смартфона LG G7 ThinQ: заявка на успех?
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Обзор appos #
# смартфона nmod Обзор
# LG appos смартфона
# G7 flat:foreign LG
# ThinQ flat:foreign LG
# : punct заявка
# заявка parataxis Обзор
# на case успех
# успех nmod заявка
# ? punct Обзор
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_78.rs3
# Total EDUs in this file: 108
# EDU 1: ##### https://www.facebook.com/mitya.aleshkovskiy/posts/10220279171028844
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://www.facebook.com/mitya.aleshkovskiy/posts/10220279171028844 appos #
# --------------------
# EDU 2: ##### Бедность в России — одна из самых главных проблем.
# # nsubj одна
# # appos #
# # punct #
# # punct #
# # punct #
# Бедность nsubj одна
# в case России
# России nmod Бедность
# — punct одна
# одна ROOT одна
# из case проблем
# самых amod главных
# главных amod проблем
# проблем nmod одна
# . punct одна
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_87.rs3
# Total EDUs in this file: 117
# EDU 1: ##### https://maxkatz.livejournal.com/742225.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://maxkatz.livejournal.com/742225.html appos #
# --------------------
# EDU 2: ##### Дорожная революция — Горпроекты идут на выборы в МГД
# # nsubj идут
# # appos #
# # punct #
# # punct #
# # punct #
# Дорожная amod революция
# революция nsubj идут
# — punct Горпроекты
# Горпроекты nmod революция
# идут ROOT идут
# на case выборы
# выборы obl идут
# в case МГД
# МГД obl идут
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_86.rs3
# Total EDUs in this file: 148
# EDU 1: ##### https://ludmilapsyholog.livejournal.com/290971.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ludmilapsyholog.livejournal.com/290971.html flat:foreign #
# --------------------
# EDU 2: ##### Опять простое решение?
# # nsubj решение
# # appos #
# # punct #
# # punct #
# # punct #
# Опять advmod решение
# простое amod решение
# решение ROOT решение
# ? punct решение
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_92.rs3
# Total EDUs in this file: 450
# EDU 1: ##### https://ru-travel.livejournal.com/33771843.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33771843.html appos #
# --------------------
# EDU 2: ##### Тао-Кларджети, потерянная Грузия: Поиски монастыря Парехи.
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Тао appos #
# - appos #
# Кларджети appos #
# , punct Грузия
# потерянная amod Грузия
# Грузия appos #
# : punct Поиски
# Поиски parataxis Грузия
# монастыря nmod Поиски
# Парехи nmod монастыря
# . punct #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_79.rs3
# Total EDUs in this file: 89
# EDU 1: ##### https://t.me/TeplitsaPRO/205
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://t.me/TeplitsaPRO/205 appos #
# --------------------
# EDU 2: ##### Поговорим о
# # nsubj Поговорим
# # appos #
# # punct #
# # punct #
# # punct #
# Поговорим ROOT Поговорим
# о punct Поговорим
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_45.rs3
# Total EDUs in this file: 168
# EDU 1: ##### https://blog.byndyu.ru/2015/05/kanban.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://blog.byndyu.ru/2015/05/kanban.html appos #
# --------------------
# EDU 2: ##### Стендапы в стиле Kanban
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Стендапы appos #
# в case стиле
# стиле nmod Стендапы
# Kanban appos стиле
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_51.rs3
# Total EDUs in this file: 138
# EDU 1: ##### http://sergeyteplyakov.blogspot.com/2013/09/blog-post_24.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://sergeyteplyakov.blogspot.com/2013/09/blog-post_24.html flat:foreign #
# --------------------
# EDU 2: ##### Культ карго в программировании
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Культ appos #
# карго nmod Культ
# в case программировании
# программировании nmod #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_47.rs3
# Total EDUs in this file: 86
# EDU 1: ##### https://medium.com/@alexandershogenov/структуры-данных-на-примере-php-spl-9a98bc08b6c0
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://medium.com/@alexandershogenov/структуры-данных-на-примере-php-spl-9a98bc08b6c0 appos #
# --------------------
# EDU 2: ##### Структуры данных(на примере PHP SPL)
# # ROOT #
# # appos #
# # appos #
# # appos #
# # appos #
# Структуры appos #
# данных(на nmod Структуры
# примере punct #
# PHP appos примере
# SPL flat:foreign PHP
# ) punct примере
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_53.rs3
# Total EDUs in this file: 101
# EDU 1: ##### https://ibigdan.livejournal.com/23770319.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ibigdan.livejournal.com/23770319.html appos #
# --------------------
# EDU 2: ##### Качели и тир
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Качели appos #
# и cc тир
# тир conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_90.rs3
# Total EDUs in this file: 70
# EDU 1: ##### https://www.facebook.com/mitya.aleshkovskiy/posts/10220212549123338
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://www.facebook.com/mitya.aleshkovskiy/posts/10220212549123338 appos #
# --------------------
# EDU 2: ##### Новость о том, что в России будут создавать филиалы колоний при крупных предприятиях
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Новость ROOT Новость
# о case том
# том nmod Новость
# , punct создавать
# что mark создавать
# в case России
# России obl создавать
# будут aux создавать
# создавать acl том
# филиалы obj создавать
# колоний nmod филиалы
# при case предприятиях
# крупных amod предприятиях
# предприятиях obl создавать
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_52.rs3
# Total EDUs in this file: 123
# EDU 1: ##### https://alexandr-rogers.livejournal.com/1162607.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://alexandr-rogers.livejournal.com/1162607.html appos #
# --------------------
# EDU 2: ##### 11:11 pm: Наркобарыги и ПМЭФ
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# 11:11 appos #
# pm appos #
# : punct Наркобарыги
# Наркобарыги parataxis #
# и cc ПМЭФ
# ПМЭФ conj Наркобарыги
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_46.rs3
# Total EDUs in this file: 158
# EDU 1: ##### https://medium.com/devschacht/anonymous-functions-in-javascript-ff6b9ba85de0
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://medium.com/devschacht/anonymous-functions-in-javascript-ff6b9ba85de0 appos #
# --------------------
# EDU 2: ##### Анонимные функции в JavaScript
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Анонимные amod функции
# функции ROOT функции
# в case JavaScript
# JavaScript nmod функции
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_63.rs3
# Total EDUs in this file: 95
# EDU 1: ##### https://marina-yudenich.livejournal.com/1393856.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://marina-yudenich.livejournal.com/1393856.html appos #
# --------------------
# EDU 2: ##### Про нефть.
# # nsubj нефть
# # appos #
# # punct #
# # punct #
# # punct #
# Про case нефть
# нефть ROOT нефть
# . punct нефть
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_77.rs3
# Total EDUs in this file: 107
# EDU 1: ##### https://miumau.livejournal.com/3097347.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://miumau.livejournal.com/3097347.html appos #
# --------------------
# EDU 2: ##### Если ваш ребенок целится туда, куда ему не попасть
# # ROOT #
# # appos #
# # punct #
# # appos #
# # punct #
# Если mark целится
# ваш det ребенок
# ребенок nsubj целится
# целится acl #
# туда advmod целится
# , punct попасть
# куда advmod попасть
# ему iobj попасть
# не advmod попасть
# попасть acl:relcl #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_88.rs3
# Total EDUs in this file: 153
# EDU 1: ##### https://maxkatz.livejournal.com/752036.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://maxkatz.livejournal.com/752036.html appos #
# --------------------
# EDU 2: ##### Преображение Петербурга — 5 примеров
# # nsubj примеров
# # appos #
# # punct #
# # punct #
# # punct #
# Преображение appos #
# Петербурга nmod Преображение
# — punct Преображение
# 5 nummod примеров
# примеров ROOT примеров
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_89.rs3
# Total EDUs in this file: 88
# EDU 1: ##### https://maxkatz.livejournal.com/727306.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://maxkatz.livejournal.com/727306.html appos #
# --------------------
# EDU 2: ##### Почему я так привязался к электробусам и почему они так важны
# # nsubj привязался
# # appos #
# # punct #
# # punct #
# # punct привязался
# Почему advmod привязался
# я nsubj привязался
# так advmod привязался
# привязался ROOT привязался
# к case электробусам
# электробусам obl привязался
# и cc важны
# почему advmod важны
# они nsubj важны
# так advmod важны
# важны conj привязался
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_76.rs3
# Total EDUs in this file: 108
# EDU 1: ##### https://veronikahlebova.ru/kak-rasskazat-detyam-o-granitsah/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://veronikahlebova.ru/kak-rasskazat-detyam-o-granitsah/ appos #
# --------------------
# EDU 2: ##### Как рассказать детям о границах
# # punct рассказать
# # appos #
# # punct #
# # punct #
# # punct #
# Как advmod рассказать
# рассказать ROOT рассказать
# детям iobj рассказать
# о case границах
# границах obl рассказать
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_62.rs3
# Total EDUs in this file: 120
# EDU 1: ##### https://marina-yudenich.livejournal.com/1384792.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://marina-yudenich.livejournal.com/1384792.html appos #
# --------------------
# EDU 2: ##### А вы ещё удивлялись, чего это Кашин так сорвался на Илью Ухова в эфире "Дождя"?
# # punct удивлялись
# # appos #
# # punct #
# # punct #
# # appos #
# А appos #
# вы nsubj удивлялись
# ещё advmod удивлялись
# удивлялись ROOT удивлялись
# , punct сорвался
# чего mark сорвался
# это nsubj Кашин
# Кашин nsubj сорвался
# так advmod сорвался
# сорвался ccomp удивлялись
# на case Илью
# Илью obl сорвался
# Ухова flat:name Илью
# в case эфире
# эфире obl сорвался
# " punct Дождя
# Дождя nmod эфире
# " punct Дождя
# ? punct удивлялись
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_48.rs3
# Total EDUs in this file: 151
# EDU 1: ##### https://eax.me/avoid-new-toys/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://eax.me/avoid-new-toys/ flat:foreign #
# --------------------
# EDU 2: ##### Десять веских причин не тащить в продакшн новые игрушки
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Десять nummod:gov причин
# веских amod причин
# причин ROOT причин
# не advmod тащить
# тащить nmod причин
# в case продакшн
# продакшн obl тащить
# новые amod игрушки
# игрушки obj тащить
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_74.rs3
# Total EDUs in this file: 96
# EDU 1: ##### https://veronikahlebova.ru/zhizn-bez-styda-i-viny/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://veronikahlebova.ru/zhizn-bez-styda-i-viny/ appos #
# --------------------
# EDU 2: ##### Жизнь без стыда и вины
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Жизнь appos #
# без case стыда
# стыда nmod Жизнь
# и cc вины
# вины conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_60.rs3
# Total EDUs in this file: 61
# EDU 1: ##### https://fritzmorgen.livejournal.com/1588453.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://fritzmorgen.livejournal.com/1588453.html flat:foreign #
# --------------------
# EDU 2: ##### Бесплатные квартиры, печь-зеркало и токсичное наследство СССР
# # nsubj квартиры
# # appos #
# # punct #
# # punct #
# # punct #
# Бесплатные amod квартиры
# квартиры ROOT квартиры
# , punct печь
# печь conj квартиры
# - conj квартиры
# зеркало conj квартиры
# и cc наследство
# токсичное amod наследство
# наследство conj квартиры
# СССР nmod наследство
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_61.rs3
# Total EDUs in this file: 83
# EDU 1: ##### https://seva-riga.livejournal.com/907963.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://seva-riga.livejournal.com/907963.html appos #
# --------------------
# EDU 2: ##### Новейшая история России внушает оптимизм
# # punct внушает
# # appos #
# # punct #
# # punct #
# # punct #
# Новейшая amod история
# история nsubj внушает
# России nmod история
# внушает ROOT внушает
# оптимизм nsubj внушает
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_75.rs3
# Total EDUs in this file: 92
# EDU 1: ##### https://veronikahlebova.ru/chto-budet-s-obshhestvom-esli-my-ne-budem-perezhivat-vinu/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://veronikahlebova.ru/chto-budet-s-obshhestvom-esli-my-ne-budem-perezhivat-vinu/ flat:foreign #
# --------------------
# EDU 2: ##### Что будет с обществом, если мы не будем переживать вину
# # nsubj обществом
# # appos #
# # punct #
# # punct #
# # appos #
# Что nsubj обществом
# будет cop обществом
# с case обществом
# обществом ROOT обществом
# , punct переживать
# если mark переживать
# мы nsubj переживать
# не advmod переживать
# будем aux переживать
# переживать advcl обществом
# вину obj переживать
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_49.rs3
# Total EDUs in this file: 139
# EDU 1: ##### https://tonsky.livejournal.com/320566.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://tonsky.livejournal.com/320566.html appos #
# --------------------
# EDU 2: ##### Пациент умер, выносите
# # nsubj умер
# # appos #
# # punct #
# # punct #
# # appos #
# Пациент nsubj умер
# умер ROOT умер
# , punct выносите
# выносите conj умер
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_65.rs3
# Total EDUs in this file: 287
# EDU 1: ##### https://evo-lutio.livejournal.com/933179.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://evo-lutio.livejournal.com/933179.html appos #
# --------------------
# EDU 2: ##### Душевные страдания
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Душевные amod страдания
# страдания ROOT страдания
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_59.rs3
# Total EDUs in this file: 85
# EDU 1: ##### https://fritzmorgen.livejournal.com/1588644.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://fritzmorgen.livejournal.com/1588644.html appos #
# --------------------
# EDU 2: ##### Станет ли Россия властелином мира?
# # nsubj Станет
# # appos #
# # punct #
# # appos #
# # punct #
# Станет ROOT Станет
# ли advmod Станет
# Россия nsubj Станет
# властелином xcomp Станет
# мира nmod властелином
# ? punct Станет
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_58.rs3
# Total EDUs in this file: 93
# EDU 1: ##### https://avmalgin.livejournal.com/8100417.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://avmalgin.livejournal.com/8100417.html appos #
# --------------------
# EDU 2: ##### У вас не должно быть тайн от товарища майора
# # nsubj должно
# # appos #
# # punct #
# # punct #
# # appos #
# У case вас
# вас obl должно
# не advmod должно
# должно ROOT должно
# быть cop тайн
# тайн nsubj должно
# от case товарища
# товарища nmod тайн
# майора nmod товарища
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_66.rs3
# Total EDUs in this file: 255
# EDU 1: ##### https://miumau.livejournal.com/3029993.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://miumau.livejournal.com/3029993.html appos #
# --------------------
# EDU 2: ##### А вот еще - про страхи
# # nsubj страхи
# # appos #
# # punct #
# # punct #
# # appos #
# А appos #
# вот advmod еще
# еще advmod страхи
# - case страхи
# про case страхи
# страхи ROOT страхи
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_72.rs3
# Total EDUs in this file: 258
# EDU 1: ##### https://evo-lutio.livejournal.com/926151.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://evo-lutio.livejournal.com/926151.html appos #
# --------------------
# EDU 2: ##### Этика и границы
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Этика nmod #
# и cc границы
# границы conj #
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_98.rs3
# Total EDUs in this file: 62
# EDU 1: ##### https://ru-travel.livejournal.com/33777634.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://ru-travel.livejournal.com/33777634.html appos #
# --------------------
# EDU 2: ##### Тень Вендена: Цесис и его замок (Латвия).
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# Тень appos #
# Вендена nmod Тень
# : punct Цесис
# Цесис parataxis Вендена
# и cc замок
# его det замок
# замок conj Цесис
# ( punct Латвия
# Латвия parataxis замок
# ) punct Латвия
# . punct Тень
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_73.rs3
# Total EDUs in this file: 76
# EDU 1: ##### https://veronikahlebova.ru/mozhno-li-delitsya-chuvstvami-s-detmi-i-esli-da-to-kakimi/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://veronikahlebova.ru/mozhno-li-delitsya-chuvstvami-s-detmi-i-esli-da-to-kakimi/ flat:foreign #
# --------------------
# EDU 2: ##### Можно ли делиться чувствами с детьми?
# # punct Можно
# # appos #
# # punct #
# # appos #
# # punct #
# Можно ROOT Можно
# ли advmod Можно
# делиться csubj Можно
# чувствами obl делиться
# с case детьми
# детьми nmod чувствами
# ? punct Можно
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_67.rs3
# Total EDUs in this file: 165
# EDU 1: ##### http://ressav.ru/vashi-konkurentnye-preimushhestva-na-sobesedovanii/
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# http://ressav.ru/vashi-konkurentnye-preimushhestva-na-sobesedovanii/ flat:foreign #
# --------------------
# EDU 2: ##### Ваши конкурентные преимущества на собеседовании
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Ваши det преимущества
# конкурентные amod преимущества
# преимущества ROOT преимущества
# на case собеседовании
# собеседовании nmod преимущества
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_17.rs3
# Total EDUs in this file: 110
# EDU 1: ##### https://my-first-time.livejournal.com/568230.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/568230.html appos #
# --------------------
# EDU 2: ##### МОИ ПЕРВЫЕ ПОИСКИ ПРОПАВШЕГО ЧЕЛОВЕКА (ТРЕНИРОВКА)
# # punct ПОИСКИ
# # appos #
# # punct #
# # punct #
# # appos #
# МОИ appos #
# ПЕРВЫЕ appos #
# ПОИСКИ ROOT ПОИСКИ
# ПРОПАВШЕГО appos ПОИСКИ
# ЧЕЛОВЕКА nmod ПРОПАВШЕГО
# ( punct ТРЕНИРОВКА
# ТРЕНИРОВКА appos ПРОПАВШЕГО
# ) punct ТРЕНИРОВКА
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_16.rs3
# Total EDUs in this file: 94
# EDU 1: ##### https://my-first-time.livejournal.com/569291.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://my-first-time.livejournal.com/569291.html appos #
# --------------------
# EDU 2: ##### Первое маленькое "не слабО"
# # nsubj слабО
# # appos #
# # punct #
# # punct #
# # punct слабО
# Первое amod маленькое
# маленькое amod слабО
# " punct слабО
# не advmod слабО
# слабО ROOT слабО
# " punct слабО
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_91-2.rs3
# Total EDUs in this file: 302
# EDU 1: ##### https://forum.awd.ru/viewtopic.php?t=357211_sid=d6736074d8cc023e5a0c79515f633c84
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://forum.awd.ru/viewtopic.php?t=357211_sid=d6736074d8cc023e5a0c79515f633c84 appos #
# --------------------
# EDU 2: ##### Патагония наоборот, с юга на север: часть 2.
# # nsubj наоборот
# # appos #
# # punct #
# # punct #
# # punct #
# Патагония appos #
# наоборот ROOT наоборот
# , punct юга
# с case юга
# юга conj наоборот
# на case север
# север nmod юга
# : punct часть
# часть parataxis наоборот
# 2 appos часть
# . punct наоборот
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_12.rs3
# Total EDUs in this file: 90
# EDU 1: ##### https://modernafrodite.kosmetista.ru/blog/93853.html
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# https://modernafrodite.kosmetista.ru/blog/93853.html appos #
# --------------------
# EDU 2: ##### И снова о голландской косметике. Увлажнение лица с Bee Honest ##### IMG
# # nsubj косметике
# # appos #
# # punct #
# # punct #
# # appos #
# И cc косметике
# снова advmod косметике
# о case косметике
# голландской amod косметике
# косметике ROOT косметике
# . punct косметике
# Увлажнение ROOT Увлажнение
# лица nmod Увлажнение
# с case Bee
# Bee nmod лица
# Honest flat:foreign Bee
# # flat:foreign Bee
# # appos Bee
# # appos Bee
# # appos Bee
# # appos Bee
# IMG flat:foreign Bee
# --------------------
# Processing file: RuRsTreebank_full/blogs/train/blogs_101.rs3
# Total EDUs in this file: 62
# EDU 1: ##### https://ru-travel.livejournal.com/33778415.html
# ...
# # punct #
# Национальное amod управление
# управление nsubj проинформировало
# ядерной amod безопасности
# безопасности nmod управление
# ( punct НУЯБ
# НУЯБ parataxis безопасности
# ) punct НУЯБ
# при case министерстве
# министерстве nmod управление
# энергетики nmod министерстве
# США nmod министерстве
# 16 obl проинформировало
# ноября flat 16
# проинформировало ROOT проинформировало
# о case третьем
# третьем obl проинформировало
# - obl проинформировало
# заключительном obl проинформировало
# - obl проинформировало
# испытании obl проинформировало
# высокоточной amod бомбы
# атомной amod бомбы
# бомбы nmod испытании
# с case уровнем
# переменным amod уровнем
# уровнем nmod бомбы
# мощности nmod уровнем
# заряда nmod мощности
# B61 appos заряда
# - appos заряда
# 12 amod версии
# - amod версии
# модернизированной amod версии
# версии nmod заряда
# созданной acl B61
# в case годах
# 1960-х amod годах
# годах obl созданной
# B61 appos версии
# . punct проинформировало
# --------------------
# Processing file: RuRsTreebank_full/news2/train/news2_44.rs3
# Total EDUs in this file: 197
# EDU 1: ##### Американская программа по использованию БПЛА против террористов является неэффективной
# # punct является
# # appos #
# # punct #
# # punct #
# # punct #
# Американская amod программа
# программа nsubj является
# по case использованию
# использованию nmod программа
# БПЛА nmod использованию
# против case террористов
# террористов nmod использованию
# является ROOT является
# неэффективной xcomp является
# --------------------
# EDU 2: ##### Американская программа по использованию боевых беспилотных летательных аппаратов (БПЛА)
# # nsubj программа
# # appos #
# # punct #
# # punct #
# # punct #
# Американская amod программа
# программа ROOT программа
# по case использованию
# использованию nmod программа
# боевых amod аппаратов
# беспилотных amod аппаратов
# летательных amod аппаратов
# аппаратов nmod использованию
# ( punct БПЛА
# БПЛА parataxis аппаратов
# ) punct БПЛА
# --------------------
# Processing file: RuRsTreebank_full/news2/train/news2_40.rs3
# Total EDUs in this file: 140
# EDU 1: ##### США и Россия должны решать мировые кризисы совместными усилиями
# # nsubj должны
# # appos #
# # punct #
# # punct #
# # appos #
# США nmod #
# и cc Россия
# Россия conj США
# должны ROOT должны
# решать xcomp должны
# мировые amod кризисы
# кризисы obj решать
# совместными amod усилиями
# усилиями obl решать
# --------------------
# EDU 2: — Сомар Виджаядаса
# — punct Сомар
# Сомар ROOT Сомар
# Виджаядаса nmod Сомар
# --------------------
# Processing file: RuRsTreebank_full/news2/train/news2_41.rs3
# Total EDUs in this file: 146
# EDU 1: ##### Международные эксперты отмечают некоторый спад в американской отрасли сланцевой нефтедобычи
# # punct отмечают
# # appos #
# # punct #
# # punct #
# # appos #
# Международные amod эксперты
# эксперты nsubj отмечают
# отмечают ROOT отмечают
# некоторый det спад
# спад obj отмечают
# в case отрасли
# американской amod отрасли
# отрасли nmod спад
# сланцевой amod нефтедобычи
# нефтедобычи nmod отрасли
# --------------------
# EDU 2: ##### Добыча сланцевой нефти на месторождениях крупнейших нефтегазодобывающих регионов Соединенных Штатов в декабре 2015 года снизится по сравнению с ноябрем на 118 тыс. баррелей в день
# # nsubj снизится
# # appos #
# # punct #
# # punct #
# # punct #
# Добыча nsubj снизится
# сланцевой amod нефти
# нефти nmod Добыча
# на case месторождениях
# месторождениях nmod Добыча
# крупнейших amod регионов
# нефтегазодобывающих amod регионов
# регионов nmod месторождениях
# Соединенных amod Штатов
# Штатов nmod регионов
# в case декабре
# декабре obl снизится
# 2015 amod года
# года nmod декабре
# снизится ROOT снизится
# по case ноябрем
# сравнению fixed по
# с fixed по
# ноябрем obl снизится
# на case баррелей
# 118 nummod тыс.
# тыс. nummod баррелей
# баррелей nmod ноябрем
# в case день
# день obl снизится
# --------------------
# Processing file: RuRsTreebank_full/news2/train/news2_43.rs3
# Total EDUs in this file: 185
# EDU 1: ##### Борьба с терроризмом требует от ЕС усиления безопасности на границе и интеграции беженцев
# # nsubj требует
# # appos #
# # punct #
# # punct #
# # appos #
# Борьба nsubj требует
# с case терроризмом
# терроризмом nmod Борьба
# требует ROOT требует
# от case ЕС
# ЕС obl требует
# усиления obj требует
# безопасности nmod усиления
# на case границе
# границе nmod безопасности
# и cc интеграции
# интеграции conj границе
# беженцев nmod усиления
# --------------------
# EDU 2: ##### Французская прокуратура объявила
# # punct объявила
# # appos #
# # punct #
# # punct #
# # punct #
# Французская amod прокуратура
# прокуратура nsubj объявила
# объявила ROOT объявила
# --------------------
# Processing file: RuRsTreebank_full/news2/train/news2_42.rs3
# Total EDUs in this file: 126
# EDU 1: ##### Программу Евросоюза по распределению беженцев необходимо довести до конца
# # nsubj необходимо
# # appos #
# # punct #
# # punct #
# # appos #
# Программу appos #
# Евросоюза nmod Программу
# по case распределению
# распределению nmod Программу
# беженцев nmod распределению
# необходимо ROOT необходимо
# довести csubj необходимо
# до case конца
# конца obl довести
# --------------------
# EDU 2: — мнение эксперта
# — punct мнение
# мнение ROOT мнение
# эксперта nmod мнение
# --------------------
# Processing file: RuRsTreebank_full/news2/dev/news2_48.rs3
# Total EDUs in this file: 234
# EDU 1: ##### Конфликт Эр-Рияда и Тегерана может замедлить процесс мирного диалога на Ближнем Востоке
# # nsubj может
# # appos #
# # punct #
# # punct #
# # punct #
# Конфликт nsubj может
# Эр nmod Конфликт
# - nmod Конфликт
# Рияда nmod Конфликт
# и cc Тегерана
# Тегерана conj Рияда
# может ROOT может
# замедлить xcomp может
# процесс obj замедлить
# мирного amod диалога
# диалога nmod процесс
# на case Востоке
# Ближнем amod Востоке
# Востоке nmod диалога
# --------------------
# EDU 2: ##### Дипломатический скандал между Саудовской Аравией и Исламской республикой Иран (ИРИ),
# # nsubj скандал
# # appos #
# # punct #
# # punct #
# # punct #
# Дипломатический amod скандал
# скандал ROOT скандал
# между case Аравией
# Саудовской amod Аравией
# Аравией nmod скандал
# и cc республикой
# Исламской amod республикой
# республикой conj Аравией
# Иран appos республикой
# ( punct ИРИ
# ИРИ parataxis Иран
# ) punct ИРИ
# , punct скандал
# --------------------
# Processing file: RuRsTreebank_full/news2/dev/news2_12.rs3
# Total EDUs in this file: 60
# EDU 1: ##### Россия: Мы не так далеки друг от друга...
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Россия appos #
# : punct далеки
# Мы nsubj далеки
# не advmod так
# так advmod далеки
# далеки parataxis Россия
# друг obl далеки
# от fixed друг
# друга fixed друг
# ... punct Россия
# --------------------
# EDU 2: ##### ... На Волге,  в моей чувашской  деревне Сюндырь-станция  про  реки Лену и Обь, про остроги   Вилюя и Верхоянска знали с пугачевских времен,
# # ROOT #
# # appos #
# # punct #
# # punct #
# # appos #
# ... punct #
# На case Волге
# Волге obl знали
# , punct деревне
#   dep ,
# в case деревне
# моей det деревне
# чувашской amod деревне
#   dep чувашской
# деревне conj Волге
# Сюндырь appos деревне
# - appos деревне
# станция appos деревне
#   dep станция
# про case реки
#   dep про
# реки nmod деревне
# Лену appos реки
# и cc Обь
# Обь conj Лену
# , punct остроги
# про case остроги
# остроги obl знали
#    dep остроги
# Вилюя nmod остроги
# и cc Верхоянска
# Верхоянска conj Вилюя
# знали ROOT знали
# с case времен
# пугачевских amod времен
# времен obl знали
# , punct знали
# --------------------
# Processing file: RuRsTreebank_full/news2/dev/news2_0.rs3
# Total EDUs in this file: 33
# EDU 1: ##### Новость: Михаил Игнатьев: «Библиотеки — центры пропаганды любви к творчеству, истории, культуре Чувашии и страны»
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Новость appos #
# : punct Михаил
# Михаил parataxis Новость
# Игнатьев flat:name Михаил
# : punct центры
# « punct центры
# Библиотеки nsubj центры
# — punct центры
# центры parataxis Михаил
# пропаганды nmod центры
# любви nmod пропаганды
# к case творчеству
# творчеству nmod любви
# , punct истории
# истории conj творчеству
# , punct культуре
# культуре conj творчеству
# Чувашии nmod культуре
# и cc страны
# страны conj Чувашии
# » punct центры
# --------------------
# EDU 2: ##### 21 сентября Президент Чувашии Михаил Игнатьев принял участие в торжественном открытии нового здания  Национальной библиотеки Чувашской Республики и в работе приуроченного к этому событию IV Форума молодых библиотекарей России.
# # nsubj принял
# # appos #
# # punct #
# # punct #
# # punct #
# 21 obl принял
# сентября flat 21
# Президент nsubj принял
# Чувашии nmod Президент
# Михаил appos Президент
# Игнатьев flat:name Михаил
# принял ROOT принял
# участие obj принял
# в case открытии
# торжественном amod открытии
# открытии nmod участие
# нового amod здания
# здания nmod открытии
#   dep здания
# Национальной amod библиотеки
# библиотеки nmod здания
# Чувашской amod Республики
# Республики nmod библиотеки
# и cc работе
# в case работе
# работе conj открытии
# приуроченного amod Форума
# к case событию
# этому det событию
# событию obl приуроченного
# IV amod Форума
# Форума nmod работе
# молодых amod библиотекарей
# библиотекарей nmod Форума
# России nmod библиотекарей
# . punct принял
# --------------------
# Processing file: RuRsTreebank_full/news2/dev/news2_24.rs3
# Total EDUs in this file: 227
# EDU 1: ##### Саммиты ШОС и БРИКС в Уфе помогут укрепить экономику и отношения между лидерами стран
# # nsubj помогут
# # appos #
# # punct #
# # punct #
# # appos #
# Саммиты appos #
# ШОС nmod Саммиты
# и cc БРИКС
# БРИКС conj ШОС
# в case Уфе
# Уфе nmod #
# помогут ROOT помогут
# укрепить xcomp помогут
# экономику obj укрепить
# и cc отношения
# отношения conj экономику
# между case лидерами
# лидерами nmod отношения
# стран nmod лидерами
# --------------------
# EDU 2: ##### Менее месяца остается до XIV саммита Шанхайской организации сотрудничества (ШОС) и VII саммита группы БРИКС,
# # nsubj остается
# # appos #
# # punct #
# # punct #
# # appos #
# Менее advmod месяца
# месяца obl остается
# остается ROOT остается
# до case саммита
# XIV amod саммита
# саммита obl остается
# Шанхайской amod организации
# организации nmod саммита
# сотрудничества nmod организации
# ( punct ШОС
# ШОС parataxis сотрудничества
# ) punct ШОС
# и cc саммита
# VII amod саммита
# саммита conj сотрудничества
# группы nmod саммита
# БРИКС appos группы
# , punct остается
# --------------------
# Processing file: RuRsTreebank_full/news2/dev/news2_36.rs3
# Total EDUs in this file: 192
# EDU 1: ##### Военная операция России в Сирии направлена на восстановление порядка и безопасности в регионе
# # punct направлена
# # appos #
# # punct #
# # punct #
# # punct #
# Военная amod операция
# операция nsubj:pass направлена
# России nmod операция
# в case Сирии
# Сирии nmod операция
# направлена ROOT направлена
# на case восстановление
# восстановление obl направлена
# порядка nmod восстановление
# и cc безопасности
# безопасности conj порядка
# в case регионе
# регионе nmod восстановление
# --------------------
# EDU 2: ##### Российская авиация за 7 дней военной операции в Сирии,
# # ROOT #
# # appos #
# # punct #
# # punct #
# # punct #
# Российская amod авиация
# авиация appos #
# за case дней
# 7 nummod дней
# дней nmod авиация
# военной amod операции
# операции nmod дней
# в case Сирии
# Сирии nmod операции
# , punct #
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_52.rs3
# Total EDUs in this file: 57
# EDU 1: УДК 355.58:004
# УДК ROOT УДК
# 355.58:004 appos УДК
# --------------------
# EDU 2: В.И. Мухин
# В.И. ROOT В.И.
# Мухин appos В.И.
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_46.rs3
# Total EDUs in this file: 144
# EDU 1: УДК 614.8:621.395.7
# УДК ROOT УДК
# 614.8:621.395.7 appos УДК
# --------------------
# EDU 2: РАЗРАБОТКА МОБИЛЬНЫХ ПРИЛОЖЕНИЙ ДЛЯ ЗАДАЧ ИНФОРМАЦИОННОЙ ПОДДЕРЖКИ СОТРУДНИКОВ ВОЕННОГО ГОСПИТАЛЯ В УСЛОВИЯХ ЧС
# РАЗРАБОТКА ROOT РАЗРАБОТКА
# МОБИЛЬНЫХ nmod РАЗРАБОТКА
# ПРИЛОЖЕНИЙ appos МОБИЛЬНЫХ
# ДЛЯ appos МОБИЛЬНЫХ
# ЗАДАЧ nmod МОБИЛЬНЫХ
# ИНФОРМАЦИОННОЙ appos РАЗРАБОТКА
# ПОДДЕРЖКИ nmod ИНФОРМАЦИОННОЙ
# СОТРУДНИКОВ nmod ПОДДЕРЖКИ
# ВОЕННОГО nmod СОТРУДНИКОВ
# ГОСПИТАЛЯ nmod ВОЕННОГО
# В case УСЛОВИЯХ
# УСЛОВИЯХ nmod РАЗРАБОТКА
# ЧС nmod РАЗРАБОТКА
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_47.rs3
# Total EDUs in this file: 169
# EDU 1: УДК 004.896
# УДК ROOT УДК
# 004.896 appos УДК
# --------------------
# EDU 2: В.В. ВИШНЕВСКИЙ*, В.Г. КАЛМЫКОВ*, Т.Н. РОМАНЕНКО*
# В.В. ROOT В.В.
# ВИШНЕВСКИЙ appos В.В.
# * appos В.В.
# , punct В.Г.
# В.Г. conj В.В.
# КАЛМЫКОВ flat:name В.Г.
# * conj В.В.
# , punct Т.Н.
# Т.Н. conj В.В.
# РОМАНЕНКО flat:name Т.Н.
# * punct В.В.
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_53.rs3
# Total EDUs in this file: 136
# EDU 1: ﻿ ОЦЕНКА ХАРАКТЕРИСТИК ФУНКЦИОНИРОВАНИЯ КОРПОРАТИВНЫХ ИНФОРМАЦИОННЫХ СИСТЕМ С НЕОДНОРОДНОЙ НАГРУЗКОЙ
# ﻿ ROOT ﻿
# ОЦЕНКА ROOT ОЦЕНКА
# ХАРАКТЕРИСТИК nmod ОЦЕНКА
# ФУНКЦИОНИРОВАНИЯ nmod ХАРАКТЕРИСТИК
# КОРПОРАТИВНЫХ nmod ОЦЕНКА
# ИНФОРМАЦИОННЫХ appos КОРПОРАТИВНЫХ
# СИСТЕМ nmod ИНФОРМАЦИОННЫХ
# С case НЕОДНОРОДНОЙ
# НЕОДНОРОДНОЙ nmod ОЦЕНКА
# НАГРУЗКОЙ nmod ОЦЕНКА
# --------------------
# EDU 2: И.В. Калинин", Э. Махаревсь, Л.А. Муравьева- Витковская11
# И.В. ROOT И.В.
# Калинин appos И.В.
# " punct И.В.
# , punct Э.
# Э. conj И.В.
# Махаревсь flat:name Э.
# , punct Л.А.
# Л.А. conj И.В.
# Муравьева- flat:name Л.А.
# Витковская11 appos И.В.
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_45.rs3
# Total EDUs in this file: 222
# EDU 1: ИНФОРМАЦИОННЫЕ ТЕХНОЛОГИИ И СИСТЕМЫ
# ИНФОРМАЦИОННЫЕ ROOT ИНФОРМАЦИОННЫЕ
# ТЕХНОЛОГИИ appos ИНФОРМАЦИОННЫЕ
# И cc СИСТЕМЫ
# СИСТЕМЫ conj ИНФОРМАЦИОННЫЕ
# --------------------
# EDU 2: УДК 001.103:002
# УДК ROOT УДК
# 001.103:002 appos УДК
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_51.rs3
# Total EDUs in this file: 213
# EDU 1: ﻿УДК 004.89
# ﻿УДК ROOT ﻿УДК
# 004.89 appos ﻿УДК
# --------------------
# EDU 2: ВЕРИФИКАЦИЯ ДАННЫХ В СИСТЕМАХ ОТСЛЕЖИВАНИЯ ЗАДАЧ С ПОМОЩЬЮ ПРОДУКЦИОННЫХ ПРАВИЛ
# ВЕРИФИКАЦИЯ ROOT ВЕРИФИКАЦИЯ
# ДАННЫХ nmod ВЕРИФИКАЦИЯ
# В case СИСТЕМАХ
# СИСТЕМАХ nmod ВЕРИФИКАЦИЯ
# ОТСЛЕЖИВАНИЯ nmod ВЕРИФИКАЦИЯ
# ЗАДАЧ nmod ОТСЛЕЖИВАНИЯ
# С case ПОМОЩЬЮ
# ПОМОЩЬЮ nmod ВЕРИФИКАЦИЯ
# ПРОДУКЦИОННЫХ nmod ВЕРИФИКАЦИЯ
# ПРАВИЛ nmod ВЕРИФИКАЦИЯ
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_50.rs3
# Total EDUs in this file: 143
# EDU 1: ﻿3 АНАЛИЗ И СИНТЕЗ СЛОЖНЫХ СИСТЕМ
# ﻿3 ROOT ﻿3
# АНАЛИЗ appos ﻿3
# И cc СИНТЕЗ
# СИНТЕЗ conj АНАЛИЗ
# СЛОЖНЫХ nmod СИНТЕЗ
# СИСТЕМ nmod ﻿3
# --------------------
# EDU 2: УДК 62-50
# УДК ROOT УДК
# 62 appos УДК
# - appos УДК
# 50 punct УДК
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_44.rs3
# Total EDUs in this file: 155
# EDU 1: ﻿УДК 624.04
# ﻿УДК ROOT ﻿УДК
# 624.04 punct ﻿УДК
# --------------------
# EDU 2: В.В. Козырева, А.А. Волков
# В.В. ROOT В.В.
# Козырева flat:name В.В.
# , punct А.А.
# А.А. conj В.В.
# Волков flat:name А.А.
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_40.rs3
# Total EDUs in this file: 78
# EDU 1: ﻿К РАЗРАБОТКЕ АЛГОРИТМА АКТИВНОГО ТЕСТИРОВАНИЯ КОРПОРАТИВНОЙ СЕТИ
# ﻿К punct РАЗРАБОТКЕ
# РАЗРАБОТКЕ ROOT РАЗРАБОТКЕ
# АЛГОРИТМА nmod РАЗРАБОТКЕ
# АКТИВНОГО nmod РАЗРАБОТКЕ
# ТЕСТИРОВАНИЯ nmod АКТИВНОГО
# КОРПОРАТИВНОЙ appos РАЗРАБОТКЕ
# СЕТИ nmod РАЗРАБОТКЕ
# --------------------
# EDU 2: Д.В. Звонов, Ф.Г. Нестерук
# Д.В. ROOT Д.В.
# Звонов appos Д.В.
# , punct Ф.Г.
# Ф.Г. conj Д.В.
# Нестерук flat:name Ф.Г.
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_54.rs3
# Total EDUs in this file: 166
# EDU 1: УДК 004.056
# УДК ROOT УДК
# 004.056 appos УДК
# --------------------
# EDU 2: АЛГОРИТМ КОНТРОЛЯ ЦЕЛОСТНОСТИ ДЕПЕРСОНАЛИЗИРОВАННЫХ ДАННЫХ В ИНФОРМАЦИОННЫХ СИСТЕМАХ ПЕРСОНАЛЬНЫХ ДАННЫХ
# АЛГОРИТМ ROOT АЛГОРИТМ
# КОНТРОЛЯ nmod АЛГОРИТМ
# ЦЕЛОСТНОСТИ nmod АЛГОРИТМ
# ДЕПЕРСОНАЛИЗИРОВАННЫХ appos АЛГОРИТМ
# ДАННЫХ nmod ДЕПЕРСОНАЛИЗИРОВАННЫХ
# В case ИНФОРМАЦИОННЫХ
# ИНФОРМАЦИОННЫХ nmod АЛГОРИТМ
# СИСТЕМАХ nmod ИНФОРМАЦИОННЫХ
# ПЕРСОНАЛЬНЫХ appos СИСТЕМАХ
# ДАННЫХ nmod АЛГОРИТМ
# --------------------
# Processing file: RuRsTreebank_full/sci.comp/sci.comp_rs3/sci.comp_41.rs3
# Traceback (most recent call last):
#
#   File ~/miniconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[10], line 7
#     root = ET.parse(rs3_path).getroot()
#
#   File ~/miniconda3/lib/python3.13/xml/etree/ElementTree.py:1204 in parse
#     tree.parse(source, parser)
#
#   File ~/miniconda3/lib/python3.13/xml/etree/ElementTree.py:569 in parse
#     self._root = parser._parse_whole(source)
#
#   File <string>
# ParseError: not well-formed (invalid token): line 44, column 125

# %% [markdown]
# ## 4. Dependency Parsing and Visualization for the First 5 EDUs

# %%
# Visualize dependency trees for the first 5 EDUs (in Jupyter only)
for idx, edu in enumerate(edus[:5]):
    print(f'EDU {idx+1}: {edu}')
    doc = nlp_ru(edu)
    displacy.render(doc, style='dep', jupyter=True)
# Out:
# EDU 1: УДК 004.056
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 5
#       3 print(f'EDU {idx+1}: {edu}')
#       4 doc = nlp_ru(edu)
# ----> 5 displacy.render(doc, style='dep', jupyter=True)
#
# File ~/miniconda3/lib/python3.13/site-packages/spacy/displacy/__init__.py:69, in render(docs, style, page, minify, jupyter, options, manual)
#      65     html = RENDER_WRAPPER(html)
#      66 if jupyter or (jupyter is None and is_in_jupyter()):
#      67     # return HTML rendered by IPython display()
#      68     # See #4840 for details on span wrapper to disable mathjax
# ---> 69     from IPython.core.display import HTML, display
#      71     return display(HTML('<span class="tex2jax_ignore">{}</span>'.format(html)))
#      72 return html
#
# ImportError: cannot import name 'display' from 'IPython.core.display' (/Users/arturbegichev/miniconda3/lib/python3.13/site-packages/IPython/core/display.py)
